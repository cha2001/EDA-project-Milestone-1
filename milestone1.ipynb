# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/HP/Downloads/housing (1).csv')

# %%
df
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.size
# Out:
# 82800

# %%
df.head()
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50       1340.0       NaN
# 1  02/05/2014 0:00  2384000.0         5       2.50       3650.0       NaN
# 2  02/05/2014 0:00   342000.0         3       2.00       1930.0       NaN
# 3  02/05/2014 0:00   420000.0         3       2.25       2000.0       NaN
# 4  02/05/2014 0:00   550000.0         4       2.50       1940.0       NaN
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0    1955.0
# 1     2.0           0     4          5        3370            280    1921.0
# 2     1.0           0     0          4        1930              0    1966.0
# 3     1.0           0     0          4        1000           1000    1963.0
# 4     1.0           0     0          4        1140            800    1976.0
#
# ...

# %%
df.tail()
# Out:
#                  date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09/07/2014 0:00  308166.6667         3       1.75       1510.0
# 4596  09/07/2014 0:00  534333.3333         3       2.50       1460.0
# 4597  09/07/2014 0:00  416904.1667         3       2.50       3010.0
# 4598  10/07/2014 0:00  203400.0000         4       2.00       2090.0
# 4599  10/07/2014 0:00  220600.0000         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595    6360.0     1.0           0     0          4        1510
# 4596    7573.0     2.0           0     0          3        1460
# 4597    7014.0     2.0           0     0          3        3010
# 4598    6630.0     1.0           0     0          3        1070
# 4599    8102.0     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0       NaN          1979     501 N 143rd St    Seattle
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4560 non-null   float64
#  5   sqft_lot       4586 non-null   float64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4577 non-null   float64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4543 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4560.000000  4.586000e+03
# mean   5.539483e+05     3.400870     2.160815   2138.935526  1.485981e+04
# std    5.808371e+05     0.908848     0.783781    965.011449  3.592050e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.225000e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.610000e+05     3.000000     2.250000   1980.000000  7.683500e+03
# 75%    6.550000e+05     4.000000     2.500000   2620.000000  1.101850e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition    sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000   4600.000000
# mean      1.512065     0.007174     0.240652     3.451739   1840.825435
# std       0.538288     0.084404     0.778405     0.677230    970.705795
# ...

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living      40
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
sns.boxplot(x=df['sqft_living'])
# Out:
# <Axes: xlabel='sqft_living'>

# %%
df['sqft_living'].unique()
# Out:
# array([ 1340.,  3650.,  1930.,  2000.,  1940.,   880.,  1350.,  2710.,
#         2430.,  1520.,  1710.,  2920.,  2330.,  1090.,  2910.,  1200.,
#         1570.,  3110.,  1370.,  1180.,  2240.,  1450.,  1750.,  2730.,
#           nan,   900.,  1650.,  1010.,  2680.,  2200.,  2530.,  2850.,
#         2280.,  1900.,  1330.,  1270.,  2170.,  2120.,  2490.,  1990.,
#         3690.,  2540.,  1800.,  2340.,  2110.,  1140.,  1480.,  1410.,
#         3180.,  2160.,  2350.,  1560.,  2740.,  1680.,  3090.,  4010.,
#         2010.,  2370.,  1840.,  2070.,  4340.,   840.,  1240.,  1390.,
#         2310.,  1050.,  2550.,  1120.,  2230.,   810.,  3190.,  1670.,
#         1970., 13540.,  1880.,  1920.,  3240.,  1550.,  2050.,  2220.,
#         1770.,  2300.,  1790.,  2440.,  1160.,  3400.,  4420.,  1571.,
#         1620.,  1408.,  3040.,  4490.,  1590.,  2450.,  1440.,  1100.,
#         2150.,  1490.,  1030.,   720.,  2020.,  1580.,  1300.,  1630.,
# ...

# %%
d1=df['sqft_living'].sort_values(ascending=True)

# %%
d1
# Out:
# 3778    370.0
# 2919    380.0
# 2416    420.0
# 1219    430.0
# 4184    490.0
#         ...
# 59        NaN
# 60        NaN
# 61        NaN
# 62        NaN
# 63        NaN
# Name: sqft_living, Length: 4600, dtype: float64

# %%
d2=df.sqft_living.median()

# %%
d2
# Out:
# 1980.0

# %%
df.sqft_living.fillna(d2,inplace=True)

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot         14
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
sns.boxplot(x=df['sqft_lot'])
# Out:
# <Axes: xlabel='sqft_lot'>

# %%
df['sqft_lot'].unique()
# Out:
# array([  nan, 9480., 9720., ..., 7573., 7014., 8102.])

# %%
c=df['sqft_lot'].sort_values(ascending=True)

# %%
c
# Out:
# 3608    638.0
# 315     681.0
# 1913    704.0
# 4004    746.0
# 3247    747.0
#         ...
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# Name: sqft_lot, Length: 4600, dtype: float64

# %%
c1=df.sqft_lot.median()

# %%
c1
# Out:
# 7683.5

# %%
df.sqft_lot.fillna(c1,inplace=True)

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built         23
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
sns.boxplot(x=df['yr_built'])
# Out:
# <Axes: xlabel='yr_built'>

# %%
df['yr_built'].unique()
# Out:
# array([1955., 1921., 1966., 1963., 1976., 1938., 1989., 1985., 1945.,
#        1948., 1909., 1980., 1939., 1965., 1956., 1997., 1987., 1983.,
#        1923., 1954., 2005., 1991., 1959., 1920., 1979., 1951., 1967.,
#        2004., 2014., 1995., 1944., 1992., 1957., 1978., 1974., 1950.,
#        1990., 1949., 1968., 1977., 1996., 2001., 2000., 1929., 2006.,
#        2008., 2009., 2012., 2013., 2007., 1986., 1973., 1988., 1900.,
#        1928., 1982., 1960., 2003., 1998., 1942., 1908., 1958., 1971.,
#        1975., 1961., 1924., 1902., 1962., 1953., 1999., 1994., 1930.,
#        1984., 2010., 1912., 1947., 1916., 1940., 1970., 1952., 1964.,
#        1926., 1905., 1969., 1903., 1943., 1993., 1946., 1910., 1904.,
#        1981., 1906., 1922., 2011., 2002., 1917., 1913., 1914., 1937.,
#        1925., 1932., 1918., 1972., 1941., 1919., 1936., 1911., 1927.,
#        1931., 1901., 1907., 1915., 1935., 1933., 1934.,   nan])

# %%
c2=df.yr_built.mean()

# %%
c2
# Out:
# 1970.8088267424077

# %%
df.yr_built.fillna(c2,inplace=True)

# %%
df.isnull().sum()
# Out:
# date              0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront        0
# view              0
# condition         0
# sqft_above        0
# sqft_basement     0
# yr_built          0
# yr_renovated      0
# street            0
# city             57
# statezip          0
# country           0
# dtype: int64

# %%
df['city'].unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', nan, 'Snoqualmie', 'Renton',
#        'Auburn', 'Sammamish', 'Kirkland', 'Issaquah', 'Des Moines',
#        'Federal Way', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Carnation', 'Newcastle',
#        'Woodinville', 'Mercer Island', 'Black Diamond', 'Ravensdale',
#        'Bothell', 'Clyde Hill', 'Algona', 'Lake Forest Park', 'Skykomish',
#        'Normandy Park', 'Tukwila', 'Vashon', 'Fall City', 'Yarrow Point',
#        'SeaTac', 'Medina', 'Enumclaw', 'Snoqualmie Pass', 'Pacific',
#        'Beaux Arts Village', 'Preston', 'Milton'], dtype=object)

# %%
k=df.city.mode()[0]
print(k)
# Out:
# Seattle

# %%
df.city.fillna(k,inplace=True)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['price'], df['bedrooms'])
ax.set_xlabel('price')
ax.set_ylabel('bedrooms')
plt.show()

# %%
data=df.iloc[:,1:14]

# %%
data
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         3       1.50       1340.0    7683.5     1.5
# 1     2.384000e+06         5       2.50       3650.0    7683.5     2.0
# 2     3.420000e+05         3       2.00       1930.0    7683.5     1.0
# 3     4.200000e+05         3       2.25       2000.0    7683.5     1.0
# 4     5.500000e+05         4       2.50       1940.0    7683.5     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05         3       1.75       1510.0    6360.0     1.0
# 4596  5.343333e+05         3       2.50       1460.0    7573.0     2.0
# 4597  4.169042e+05         3       2.50       3010.0    7014.0     2.0
# 4598  2.034000e+05         4       2.00       2090.0    6630.0     1.0
# 4599  2.206000e+05         3       2.50       1490.0    8102.0     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement     yr_built  \
# ...

# %%
q1=data.quantile(0.25)

# %%
q1
# Out:
# price            322500.00
# bedrooms              3.00
# bathrooms             1.75
# sqft_living        1470.00
# sqft_lot           5001.00
# floors                1.00
# waterfront            0.00
# view                  0.00
# condition             3.00
# sqft_above         1190.00
# sqft_basement         0.00
# yr_built           1951.00
# yr_renovated          0.00
# Name: 0.25, dtype: float64

# %%
q3=data.quantile(0.75)

# %%
q3
# Out:
# price            655000.0
# bedrooms              4.0
# bathrooms             2.5
# sqft_living        2610.0
# sqft_lot          11000.0
# floors                2.0
# waterfront            0.0
# view                  0.0
# condition             4.0
# sqft_above         2300.0
# sqft_basement       610.0
# yr_built           1997.0
# yr_renovated       1999.0
# Name: 0.75, dtype: float64

# %%
IQR=q3-q1
print(IQR)
# Out:
# price            332500.00
# bedrooms              1.00
# bathrooms             0.75
# sqft_living        1140.00
# sqft_lot           5999.00
# floors                1.00
# waterfront            0.00
# view                  0.00
# condition             1.00
# sqft_above         1110.00
# sqft_basement       610.00
# yr_built             46.00
# yr_renovated       1999.00
# dtype: float64

# %%
print((data < (q1 - 1.5 * IQR)) | (data > (q3 + 1.5 * IQR)))
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0     False     False      False        False     False   False       False
# 1      True     False      False        False     False   False       False
# 2     False     False      False        False     False   False       False
# 3     False     False      False        False     False   False       False
# 4     False     False      False        False     False   False       False
# ...     ...       ...        ...          ...       ...     ...         ...
# 4595  False     False      False        False     False   False       False
# 4596  False     False      False        False     False   False       False
# 4597  False     False      False        False     False   False       False
# 4598  False     False      False        False     False   False       False
# 4599  False     False      False        False     False   False       False
#
# ...

# %%
v=(data < (q1 - 1.5 * IQR)) | (data > (q3 + 1.5 * IQR))

# %%
v.sum()
# Out:
# price            241
# bedrooms         118
# bathrooms        141
# sqft_living      134
# sqft_lot         545
# floors             0
# waterfront        33
# view             460
# condition          6
# sqft_above       121
# sqft_basement     82
# yr_built           0
# yr_renovated       0
# dtype: int64

# %%
df.shape
# Out:
# (4600, 18)

# %%
data_clean = data[~((data < (q1 - 1.5 * IQR)) | (data > (q3 + 1.5 * IQR))).any(axis=1)]

# %%
data_clean.shape
# Out:
# (3442, 13)

# %%
data_clean
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     313000.0000         3       1.50       1340.0    7683.5     1.5
# 2     342000.0000         3       2.00       1930.0    7683.5     1.0
# 3     420000.0000         3       2.25       2000.0    7683.5     1.0
# 4     550000.0000         4       2.50       1940.0    7683.5     1.0
# 5     490000.0000         2       1.00        880.0    7683.5     1.0
# ...           ...       ...        ...          ...       ...     ...
# 4595  308166.6667         3       1.75       1510.0    6360.0     1.0
# 4596  534333.3333         3       2.50       1460.0    7573.0     2.0
# 4597  416904.1667         3       2.50       3010.0    7014.0     2.0
# 4598  203400.0000         4       2.00       2090.0    6630.0     1.0
# 4599  220600.0000         3       2.50       1490.0    8102.0     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement     yr_built  \
# ...

# %%
data.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.192793   0.319311     0.419000  0.048293  0.143775
# bedrooms       0.192793  1.000000   0.545920     0.593302  0.068796  0.177895
# bathrooms      0.319311  0.545920   1.000000     0.760145  0.107251  0.486428
# sqft_living    0.419000  0.593302   0.760145     1.000000  0.209090  0.343607
# sqft_lot       0.048293  0.068796   0.107251     0.209090  1.000000  0.003832
# floors         0.143775  0.177895   0.486428     0.343607  0.003832  1.000000
# waterfront     0.131387 -0.003483   0.076232     0.118055  0.017283  0.022024
# view           0.220758  0.111028   0.211960     0.310315  0.074024  0.031211
# condition      0.036660  0.025080  -0.119994    -0.061593  0.000406 -0.275013
# sqft_above     0.311732  0.429573   0.612828     0.772572  0.200370  0.460266
# sqft_basement  0.208591  0.334165   0.298020     0.446905  0.034200 -0.255510
# ...

# %%
sns.pairplot(data)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
b=data.corr()
plt.figure(figsize=(12,12))
sns.heatmap(b,annot=True,cmap='grey')
# Out:
# <Axes: >
